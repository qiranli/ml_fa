# %%
import pandas as pd
import numpy as np
from glob import glob

# %%
# INPUTS------------------------------------------------------------------
# Number of Components
k = 4
# Component names
variable = ['angle1','angle2','angle3','angle4']

# layer names
# Used for extracting corresponding layer size for design while reading
# the des file
layer_name = ['m[0]','m[1]','m[2]','m[3]']

# Max number of layers
max_len = 20
#----- END INPUTS---------------------------------------------------------

# %%
files = glob("./redundancy_check_for_existing_runs-twoobj_cf/*.des")

df_red = pd.DataFrame(columns=['File Name','Logic Repeated(%)','Conventional Repeated(%)','Overall Repeated(%)'])
df_red['File Name'] = pd.Series(files)

def get_label_line(des_file):
    f = open(des_file,'rb')
    lines = f.readlines()
    line_end = len(lines)
    
    start_table = 0
    
    # Find the line with variable names
    for i in range(len(lines)):
        line_tmp = lines[i].split()

        try:
            if line_tmp[0]=='<ID>':
                label_line = line_tmp
                start_table = i+1
                break
        except:
            pass
        
    return label_line,start_table
        

# Function to collect final component layers
def get_component_layers(key,n,line,pos):
    comp = line[pos[key]:pos[key]+n[key]]
    comp = [str(int(float(k))) for k in comp]
    comp = "".join(comp)
    return comp

def get_layer(n,line,pos,variable=variable):
    # Get component final layers
    comps = [get_component_layers(x,n,line,pos) for x in variable]
    return comps
            
    
for des_file in files:
    
    df1 = pd.DataFrame(columns=variable)
    
    label_line,start_table = get_label_line(des_file)
    
    f = open(des_file,'rb')
    lines = f.readlines()
    line_end = len(lines)
    
    # Create a position dictionary for starting point of the component layer
    start_pos = [label_line.index(x + '[0]') for x in variable]
    pos_dict = dict(zip(variable,start_pos))
    
    
    # Find the line with variable names
    for i in range(start_table,line_end):
        line = lines[i].split()

        # Create a layer_size position dict
        layer_size = [int(float(line[label_line.index(x)])) for x in layer_name]
        layer_dict = dict(zip(variable,layer_size))
        
        layer = get_layer(layer_dict,line,pos_dict)
        
        df_tmp = pd.DataFrame([layer],columns=variable)
        df1 = df1.append(df_tmp,ignore_index=True)
        
    rep = df1[df1.duplicated(keep='first')].shape[0]
    rep_perc = rep*100./(df1.shape[0])
    df_red['Logic Repeated(%)'][df_red['File Name'] == des_file] = rep_perc
    
    conv_rep = df1.shape[0]
    df_red['Conventional Repeated(%)'][df_red['File Name']== des_file] = conv_rep*100/4800.
    
    overall_rep_perc = (conv_rep + rep)*100/4800. 
    df_red['Overall Repeated(%)'][df_red['File Name']== des_file] = overall_rep_perc 
        
    print("Completed:    %s"%des_file)    
    
df_red.to_csv("redundancy_check_for_existing_runs-twoobj_cf.csv",index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-aa18fbb2049a> in <module>()
#      72
#      73     conv_rep = df1.shape[0]
# ---> 74     df_red['Conventional Repeated(%)'][df_red['File_name']== des_file] = conv_rep*100/4800.
#      75
#      76     overall_rep_perc = (conv_rep + rep)*100/4800.
#
# C:\Anaconda2\lib\site-packages\pandas\core\frame.pyc in __getitem__(self, key)
#    1962
#    1963                 return result
# -> 1964
#    1965     def iget_value(self, i, j):
#    1966         """
#
# C:\Anaconda2\lib\site-packages\pandas\core\frame.pyc in _getitem_column(self, key)
#    1969         warnings.warn("iget_value(i, j) is deprecated. Please use .iat[i, j]",
#    1970                       FutureWarning, stacklevel=2)
# -> 1971         return self.iat[i, j]
#    1972
#    1973     def __getitem__(self, key):
#
# C:\Anaconda2\lib\site-packages\pandas\core\generic.pyc in _get_item_cache(self, item)
#    1643     def xs(self, key, axis=0, level=None, copy=None, drop_level=True):
#    1644         """
# -> 1645         Returns a cross-section (row(s) or column(s)) from the
#    1646         Series/DataFrame. Defaults to cross-section on the rows (axis=0).
#    1647
#
# C:\Anaconda2\lib\site-packages\pandas\core\internals.pyc in get(self, item, fastpath)
#    3588         if axis >= self.ndim:
#    3589             raise IndexError("Requested axis not found in manager")
# -> 3590
#    3591         if axis == 0:
#    3592             new_blocks = self._slice_take_blocks_ax0(indexer,
#
# C:\Anaconda2\lib\site-packages\pandas\core\indexes\base.pyc in get_loc(self, key, method, tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5280)()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5126)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20523)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20477)()
#
# KeyError: 'File_name'

# %%
df_red
# Out:
#                                             File Name Repeated Percentage (%)
# 0   ./redundancy_check_for_existing_runs-twoobj_cf...                 45.6193
# 1   ./redundancy_check_for_existing_runs-twoobj_cf...                 54.1822
# 2   ./redundancy_check_for_existing_runs-twoobj_cf...                 40.9466
# 3   ./redundancy_check_for_existing_runs-twoobj_cf...                 41.5187
# 4   ./redundancy_check_for_existing_runs-twoobj_cf...                 49.8294
# 5   ./redundancy_check_for_existing_runs-twoobj_cf...                 13.9217
# 6   ./redundancy_check_for_existing_runs-twoobj_cf...                  18.235
# 7   ./redundancy_check_for_existing_runs-twoobj_cf...                  27.507
# 8   ./redundancy_check_for_existing_runs-twoobj_cf...                 16.6158
# 9   ./redundancy_check_for_existing_runs-twoobj_cf...                 17.2589
# 10  ./redundancy_check_for_existing_runs-twoobj_cf...                 22.6351
# 11  ./redundancy_check_for_existing_runs-twoobj_cf...                 54.1822
# 12  ./redundancy_check_for_existing_runs-twoobj_cf...                 25.8826
# 13  ./redundancy_check_for_existing_runs-twoobj_cf...                 23.8644
# 14  ./redundancy_check_for_existing_runs-twoobj_cf...                 21.4106
# 15  ./redundancy_check_for_existing_runs-twoobj_cf...                 25.0385
# 16  ./redundancy_check_for_existing_runs-twoobj_cf...                 28.5022
# 17  ./redundancy_check_for_existing_runs-twoobj_cf...                 23.0684
# 18  ./redundancy_check_for_existing_runs-twoobj_cf...                 21.2308
# 19  ./redundancy_check_for_existing_runs-twoobj_cf...                  28.756

# %%
files[6:8]
# Out:
# ['./redundancy_check_for_existing_runs\\moga-steadystate-seed2.des',
#  './redundancy_check_for_existing_runs\\moga-steadystate-seed3.des']
