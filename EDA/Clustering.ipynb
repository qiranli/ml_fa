# %%
import pandas as pd
import numpy as np
import pickle
from sklearn.cluster import KMeans
from sklearn import datasets
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
time_s_card = pickle.load(open("time_s_card.pkl","rb"))
trend_card = pickle.load(open("trend_card_15.pkl","rb"))

# %%
# test for mean

col1 = trend_card["AAPL"][0].index.tolist()
col2 = trend_card["AAPL"][1].index.tolist()

cols = col1 + col2

df = pd.DataFrame(columns=cols)

ticks = trend_card.keys()

for tick in ticks:
    try:
        df.loc[tick] = list(trend_card[tick][0]["mean"].values) + list(trend_card[tick][1]["mean"].values)
    except:
        pass

# %%
df = df.replace([np.inf, -np.inf], np.nan)
df = df.fillna(0.)

# %%
df2 = df[["pb","pe"]]
df2.head()
# Out:
#            pb         pe
# SPH  7.453103  98.950196
# SPN  1.862855   9.684711
# SPA  1.379825  68.871873
# SPE  0.000000   0.000000
# SPG  6.633838  39.707745

# %%
X = df2.as_matrix()

# %%
plt.scatter(X[:,0],X[:,1])
plt.ylim((-20,60))
plt.xlim((-5,10))
# Out:
# (-5, 10)

# %%
X.shape
# Out:
# (3237L, 2L)
